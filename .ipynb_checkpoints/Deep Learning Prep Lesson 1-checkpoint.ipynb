# %% [markdown]
# # Deep Learning
# ### _Lesson 1_
#
# Week1:
# 1. Regression Models
# 2. Intro to Neurl networks, perceptrons, train networks)
# 3. First neural networks with only Numpy
#
# Perceptron is a type of linear classifier (a classification algorithm that makes its predictions based on a linear predictor function combining a set of weights with the feature vector).
#
# Perceptron is an algorithm for learning a binary classifier: a function that maps its input x (a rela valued vector) to an output value of f(x). Logistic regression isn't a perceptron.
#
# Key commands for managing environments:
# 1. source deactivate
# 2. source activate my_env
# 3. conda create -n py3 python=3
# 4. conda env export > environment.yaml
# 5. conda env create -f environment.yaml
# 6. conda env remove -n env_name
#
# Running a notebook server locally:
# jupyter notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ```
# import requests
# response = requests.get('https://www.udacity.com')
# ```
#
# $$
# y=\frac{a}{b+c}
# $$

# %% [markdown]
# Magic commands %matplotlib

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' 

import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,1,300)
for w in range(2,6,2):
    plt.plot(x,np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %% [markdown]
# Can use nbconvert in terminal with the following command to convert all to html json file
# commands
#
#     jupyter nbconvert --to html notebook.ipynb
#
# ## Creating slide show from just the notebook, use the following command
#
#     jupyter nbconvert notebook.ipynb --to slides
#
# For immediate use:
#
#     jupyter nbconvert notebook.ipynb --to slides --post serve

# %% [markdown]
# ## Core codes for fast style transfer
#
# Setting up the environment
#
#     conda create -n style-transfer python=2.7.9
#     source activate style-transfer
#     pip install tensorflow
#     conda install scipy pillow
#
#
# Running the actual code for fast style transfer
#
#     python evaluate.py --checkpoint ./rain-princess.ckpt --in-path <path_to_input_file> --out-path ./output_image.jpg

# %% [markdown]
# # 10 Minutes to Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

s=pd.Series([1,3,5,np.nan,6,8])
s
dates=pd.date_range('20130101',periods=6)
dates
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.046585  1.218894  0.497901 -0.323956
# 2013-01-02 -0.280142 -0.577619  0.815974  0.456893
# 2013-01-03  0.790894 -0.163223 -1.565743  1.435366
# 2013-01-04 -0.432238 -1.042169 -1.402222  0.789669
# 2013-01-05 -0.519047  1.483288  0.971490  1.274204
# 2013-01-06  2.309237 -0.129820 -0.436454 -0.743999

# %%
df2 = pd.DataFrame({ 'A' : 1.,'B' : pd.Timestamp('20130102'),
'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
'D' : np.array([3] * 4,dtype='int32'),
'E' : pd.Categorical(["test","train","test","train"]),
'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.046585  1.218894  0.497901 -0.323956
# 2013-01-02 -0.280142 -0.577619  0.815974  0.456893
# 2013-01-03  0.790894 -0.163223 -1.565743  1.435366
# 2013-01-04 -0.432238 -1.042169 -1.402222  0.789669
# 2013-01-05 -0.519047  1.483288  0.971490  1.274204

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02 -0.280142 -0.577619  0.815974  0.456893
# 2013-01-03  0.790894 -0.163223 -1.565743  1.435366
# 2013-01-04 -0.432238 -1.042169 -1.402222  0.789669
# 2013-01-05 -0.519047  1.483288  0.971490  1.274204
# 2013-01-06  2.309237 -0.129820 -0.436454 -0.743999

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.04658481,  1.2188937 ,  0.49790058, -0.32395645],
#        [-0.28014203, -0.57761852,  0.81597366,  0.45689273],
#        [ 0.79089392, -0.16322292, -1.5657433 ,  1.43536646],
#        [-0.43223782, -1.04216923, -1.40222194,  0.78966898],
#        [-0.51904746,  1.48328781,  0.97148998,  1.27420433],
#        [ 2.30923717, -0.12981992, -0.43645431, -0.7439988 ]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.303686  0.131558 -0.186509  0.481363
# std    1.090103  1.004515  1.118666  0.869991
# min   -0.519047 -1.042169 -1.565743 -0.743999
# 25%   -0.394214 -0.474020 -1.160780 -0.128744
# 50%   -0.163363 -0.146521  0.030723  0.623281
# 75%    0.581524  0.881715  0.736455  1.153070
# max    2.309237  1.483288  0.971490  1.435366

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.046585   -0.280142    0.790894   -0.432238   -0.519047    2.309237
# B    1.218894   -0.577619   -0.163223   -1.042169    1.483288   -0.129820
# C    0.497901    0.815974   -1.565743   -1.402222    0.971490   -0.436454
# D   -0.323956    0.456893    1.435366    0.789669    1.274204   -0.743999

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.323956  0.497901  1.218894 -0.046585
# 2013-01-02  0.456893  0.815974 -0.577619 -0.280142
# 2013-01-03  1.435366 -1.565743 -0.163223  0.790894
# 2013-01-04  0.789669 -1.402222 -1.042169 -0.432238
# 2013-01-05  1.274204  0.971490  1.483288 -0.519047
# 2013-01-06 -0.743999 -0.436454 -0.129820  2.309237

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-04 -0.432238 -1.042169 -1.402222  0.789669
# 2013-01-02 -0.280142 -0.577619  0.815974  0.456893
# 2013-01-03  0.790894 -0.163223 -1.565743  1.435366
# 2013-01-06  2.309237 -0.129820 -0.436454 -0.743999
# 2013-01-01 -0.046585  1.218894  0.497901 -0.323956
# 2013-01-05 -0.519047  1.483288  0.971490  1.274204

# %%
df["A"]
# Out:
# 2013-01-01   -0.046585
# 2013-01-02   -0.280142
# 2013-01-03    0.790894
# 2013-01-04   -0.432238
# 2013-01-05   -0.519047
# 2013-01-06    2.309237
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.046585  1.218894  0.497901 -0.323956
# 2013-01-02 -0.280142 -0.577619  0.815974  0.456893
# 2013-01-03  0.790894 -0.163223 -1.565743  1.435366

# %% [markdown]
# # Intro to machine learning with Scikit-learn

# %%
from sklearn import datasets
iris=datasets.load_iris()
digits=datasets.load_digits()

# %%
print(digits.data)
# Out:
# [[  0.   0.   5. ...,   0.   0.   0.]
#  [  0.   0.   0. ...,  10.   0.   0.]
#  [  0.   0.   0. ...,  16.   9.   0.]
#  ...,
#  [  0.   0.   1. ...,   6.   0.   0.]
#  [  0.   0.   2. ...,  12.   0.   0.]
#  [  0.   0.  10. ...,  12.   1.   0.]]

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
digits.images[0]
# Out:
# array([[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#        [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
#        [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
#        [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
#        [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
#        [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
#        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]])

# %%
from sklearn import svm

# %%
clf=svm.SVC(gamma=0.001,C=100.)
clf.fit(digits.data[:-1],digits.target[:-1])
clf.predict(digits.data[-1:])
# Out:
# array([8])

# %% [markdown]
# # Model Persistence

# %%
from sklearn import svm
from sklearn import datasets
clf=svm.SVC()
iris=datasets.load_iris()
X,y=iris.data, iris.target
clf.fit(X,y)
import pickle
s=pickle.dumps(clf)
s=pickle.dumps(clf)
clf2=pickle.loads(s)
clf2.predict(X[0:1])
y[0]
# Out:
# 0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel("some numbers")
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0., 5., 0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %% [markdown]
# # Siraj's Intro to deep learning

# %% [markdown]
# 1. Supervised Learning (Feedback every step along the way)
# 2. Unsupervised Learning
# 3. Reinforcement Learning (model isn't getting a feedback immediately and only feedback when goal is achieved - linked to interacting with the environment through trial and error)

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

#read data
dataframe=pd.read_fwf('./linear_regression_demo/brain_body.txt')
x_values=dataframe[["Brain"]]
y_values=dataframe[["Body"]]

#train model on data
body_reg=linear_model.LinearRegression()
body_reg.fit(x_values,y_values)
